# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Computer_Vision"
# Out:
# Face_Mask_Detection.ipynb	 Real_Time_Object_Detection.ipynb
# License_Plate_Recognition.ipynb  Untitled0.ipynb

# %%
# !cp -r "/content/drive/MyDrive/cv-projects" /content/
